# %%
import numpy as np
import os

import matplotlib.pyplot as plt
import seaborn as sns

from matplotlib import cm
# %matplotlib inline
sns.set_theme()
sns.set(font_scale=1.25)

# %% [markdown]
# # Linear encoding

# %% [markdown]
# ## Benchmark - Plot for each epoch

# %%
min_layers, max_layers = 1,4
min_sublayers, max_sublayers = 1,2

cmap = cm.get_cmap('plasma', (max_layers-min_layers+1)*(max_sublayers-min_sublayers+1)+1)

fig, ax = plt.subplots(figsize=(8,4))
# ax.set_ylim(0.05,.4)

#inset settings
axin_1 = ax.inset_axes([0.5, 0.5, 0.4, 0.45])
axin_1.set_ylim([0.055, 0.16])
axin_1.set_xlim([80, 100])
ax.indicate_inset_zoom(axin_1, edgecolor='grey',)#'black'
plt.setp(axin_1.spines.values(), color='black')

i = 0

for layers in range(min_layers, max_layers+1):
    for sublayers in range(min_sublayers, max_sublayers+1):

        dir_path = '..'

        data = dir_path+f'/results/linear/{layers}l-{sublayers}p'
        val_cost = np.load(data+'/val_cost_per_epoch.npy', )
        train_cost = np.load(data+'/train_cost_per_epoch.npy', )


        pl1, = ax.plot(train_cost,linestyle='dashed',# label=f'{layers} l, {sublayers}sl - Train', 
                       c=cmap(i),  )#alpha=0.5
        axin_1.plot(train_cost,linestyle='dashed',# label=f'{layers} l, {sublayers}sl - Train', 
                    c=cmap(i),  )#alpha=0.5
        pl2, = ax.plot(val_cost, label=f'{layers} l, {sublayers}sl',
                       c=cmap(i))
        axin_1.plot(val_cost, label=f'{layers} l, {sublayers}sl',
                    c=cmap(i))
        i+=1



ax.set_ylabel('MSE')
ax.set_xlabel('Epochs')
lgd = ax.legend(bbox_to_anchor=(.0, 1.3), ncol=4, loc='upper left')#
# ax.add_artist(lgd)
# lgd1 = ax.legend([pl1,pl2],['Train','Val'], loc='lower left',bbox_to_anchor=(0.1, 0.3))#
# ax.add_artist(lgd)
#creating a folder to save the plot
dir_path = '..'
data = dir_path+f'/plots/linear'
os.makedirs(data,  0o755,  exist_ok=True)

fig.savefig(data+'/benchmark_compare_mse_per_epoch.pdf',
            bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.show()
# Out:
# /var/folders/6w/dmgtk2bn4jx1mdj87jl8c6sh0000gn/T/ipykernel_18495/47430373.py:4: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('plasma', (max_layers-min_layers+1)*(max_sublayers-min_sublayers+1)+1)

# %% [markdown]
# ## Benchmark - Plot for each iteration

# %%
min_layers, max_layers = 1,4
min_sublayers, max_sublayers = 1,2

cmap = cm.get_cmap('plasma', (max_layers-min_layers+1)*(max_sublayers-min_sublayers+1)+1)

fig, ax = plt.subplots(figsize=(8,4))
# ax.set_ylim(0.1,1.65)

i = 0

for layers in range(min_layers, max_layers+1):
    for sublayers in range(min_sublayers, max_sublayers+1):

        dir_path = '..'

        data = dir_path+f'/results/linear/{layers}l-{sublayers}p'
        val_cost = np.load(data+'/val_cost.npy', )
        train_cost = np.load(data+'/train_cost.npy', )


        pl1, = ax.plot(train_cost,linestyle='dashed',# label=f'{layers} l, {sublayers}sl - Train', 
                       c=cmap(i),  )#alpha=0.5
        pl2, = ax.plot(val_cost, label=f'{layers} l, {sublayers}sl',
                       c=cmap(i))
        i+=1


ax.set_ylabel('MSE')
ax.set_xlabel('Iterations')
lgd = ax.legend(bbox_to_anchor=(.95, 1.3), ncol=4)#
# ax.add_artist(lgd)
# lgd1 = ax.legend([pl1,pl2],['Train','Val'], loc='lower left',bbox_to_anchor=(0.1, 0.3))#
# ax.add_artist(lgd)
#creating a folder to save the plot
dir_path = '..'
data = dir_path+f'/plots/linear'
os.makedirs(data,  0o755,  exist_ok=True)

fig.savefig(data+'/benchmark_compare_mse.pdf',
            bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.show()
# Out:
# /var/folders/6w/dmgtk2bn4jx1mdj87jl8c6sh0000gn/T/ipykernel_18495/839573998.py:4: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('plasma', (max_layers-min_layers+1)*(max_sublayers-min_sublayers+1)+1)

# %% [markdown]
# ## FR - With Outliers - Plot for each epoch

# %%
min_layers, max_layers = 1,4
min_sublayers, max_sublayers = 1,2

cmap = cm.get_cmap('plasma', (max_layers-min_layers+1)*(max_sublayers-min_sublayers+1)+1)

fig, ax = plt.subplots(figsize=(8,4))
# ax.set_ylim(0.05,.4)

#inset settings
axin_1 = ax.inset_axes([0.5, 0.5, 0.4, 0.45])
axin_1.set_ylim([0.055, 0.16])
axin_1.set_xlim([50, 60])
ax.indicate_inset_zoom(axin_1, edgecolor='grey',)#'black'
plt.setp(axin_1.spines.values(), color='black')

i = 0

for layers in range(min_layers, max_layers+1):
    for sublayers in range(min_sublayers, max_sublayers+1):

        dir_path = '..'

        data = dir_path+f'/results/linear_with_outliers/{layers}l-{sublayers}p'
        val_cost = np.load(data+'/val_cost_per_epoch.npy', )
        train_cost = np.load(data+'/train_cost_per_epoch.npy', )


        pl1, = ax.plot(train_cost,linestyle='dashed',# label=f'{layers} l, {sublayers}sl - Train', 
                       c=cmap(i),  )#alpha=0.5
        axin_1.plot(train_cost,linestyle='dashed',# label=f'{layers} l, {sublayers}sl - Train', 
                    c=cmap(i),  )#alpha=0.5
        pl2, = ax.plot(val_cost, label=f'{layers} l, {sublayers}sl',
                       c=cmap(i))
        axin_1.plot(val_cost, label=f'{layers} l, {sublayers}sl',
                    c=cmap(i))
        i+=1



ax.set_ylabel('MSE')
ax.set_xlabel('Epochs')
lgd = ax.legend(bbox_to_anchor=(.0, 1.3), ncol=4, loc='upper left')#
# ax.add_artist(lgd)
# lgd1 = ax.legend([pl1,pl2],['Train','Val'], loc='lower left',bbox_to_anchor=(0.1, 0.3))#
# ax.add_artist(lgd)
#creating a folder to save the plot
dir_path = '..'
data = dir_path+f'/plots/linear'
os.makedirs(data,  0o755,  exist_ok=True)

fig.savefig(data+'/with_outliers_compare_mse_per_epoch.pdf',
            bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.show()
# Out:
# /var/folders/6w/dmgtk2bn4jx1mdj87jl8c6sh0000gn/T/ipykernel_18495/1400442327.py:4: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('plasma', (max_layers-min_layers+1)*(max_sublayers-min_sublayers+1)+1)

# %% [markdown]
# ## FR - With Outliers - Plot for each iteration

# %%
min_layers, max_layers = 1,4
min_sublayers, max_sublayers = 1,2

cmap = cm.get_cmap('plasma', (max_layers-min_layers+1)*(max_sublayers-min_sublayers+1)+1)

fig, ax = plt.subplots(figsize=(8,4))
# ax.set_ylim(0.1,1.65)

i = 0

for layers in range(min_layers, max_layers+1):
    for sublayers in range(min_sublayers, max_sublayers+1):

        dir_path = '..'

        data = dir_path+f'/results/linear_with_outliers/{layers}l-{sublayers}p'
        val_cost = np.load(data+'/val_cost.npy', )
        train_cost = np.load(data+'/train_cost.npy', )


        pl1, = ax.plot(train_cost,linestyle='dashed',# label=f'{layers} l, {sublayers}sl - Train', 
                       c=cmap(i),  )#alpha=0.5
        pl2, = ax.plot(val_cost, label=f'{layers} l, {sublayers}sl',
                       c=cmap(i))
        i+=1


ax.set_ylabel('MSE')
ax.set_xlabel('Iterations')
lgd = ax.legend(bbox_to_anchor=(.95, 1.3), ncol=4)#
# ax.add_artist(lgd)
# lgd1 = ax.legend([pl1,pl2],['Train','Val'], loc='lower left',bbox_to_anchor=(0.1, 0.3))#
# ax.add_artist(lgd)
#creating a folder to save the plot
dir_path = '..'
data = dir_path+f'/plots/linear'
os.makedirs(data,  0o755,  exist_ok=True)

fig.savefig(data+'/with_outliers_compare_mse.pdf',
            bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.show()
# Out:
# /var/folders/6w/dmgtk2bn4jx1mdj87jl8c6sh0000gn/T/ipykernel_18495/1729243332.py:4: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('plasma', (max_layers-min_layers+1)*(max_sublayers-min_sublayers+1)+1)

# %% [markdown]
# ## FR - No Outliers - Plot for each epoch

# %%
min_layers, max_layers = 1,4
min_sublayers, max_sublayers = 1,2

cmap = cm.get_cmap('plasma', (max_layers-min_layers+1)*(max_sublayers-min_sublayers+1)+1)

fig, ax = plt.subplots(figsize=(8,4))
# ax.set_ylim(0.05,.4)

#inset settings
axin_1 = ax.inset_axes([0.5, 0.5, 0.4, 0.45])
axin_1.set_ylim([0.055, 0.16])
axin_1.set_xlim([50, 60])
ax.indicate_inset_zoom(axin_1, edgecolor='grey',)#'black'
plt.setp(axin_1.spines.values(), color='black')

i = 0

for layers in range(min_layers, max_layers+1):
    for sublayers in range(min_sublayers, max_sublayers+1):

        dir_path = '..'

        data = dir_path+f'/results/linear_no_outliers/{layers}l-{sublayers}p'
        val_cost = np.load(data+'/val_cost_per_epoch.npy', )
        train_cost = np.load(data+'/train_cost_per_epoch.npy', )


        pl1, = ax.plot(train_cost,linestyle='dashed',# label=f'{layers} l, {sublayers}sl - Train', 
                       c=cmap(i),  )#alpha=0.5
        axin_1.plot(train_cost,linestyle='dashed',# label=f'{layers} l, {sublayers}sl - Train', 
                    c=cmap(i),  )#alpha=0.5
        pl2, = ax.plot(val_cost, label=f'{layers} l, {sublayers}sl',
                       c=cmap(i))
        axin_1.plot(val_cost, label=f'{layers} l, {sublayers}sl',
                    c=cmap(i))
        i+=1



ax.set_ylabel('MSE')
ax.set_xlabel('Epochs')
lgd = ax.legend(bbox_to_anchor=(.0, 1.3), ncol=4, loc='upper left')#
# ax.add_artist(lgd)
# lgd1 = ax.legend([pl1,pl2],['Train','Val'], loc='lower left',bbox_to_anchor=(0.1, 0.3))#
# ax.add_artist(lgd)
#creating a folder to save the plot
dir_path = '..'
data = dir_path+f'/plots/linear'
os.makedirs(data,  0o755,  exist_ok=True)

fig.savefig(data+'/no_outliers_compare_mse_per_epoch.pdf',
            bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.show()
# Out:
# /var/folders/6w/dmgtk2bn4jx1mdj87jl8c6sh0000gn/T/ipykernel_18495/1073242133.py:4: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('plasma', (max_layers-min_layers+1)*(max_sublayers-min_sublayers+1)+1)

# %% [markdown]
# ## FR - No Outliers - Plot for each iteration

# %%
min_layers, max_layers = 1,4
min_sublayers, max_sublayers = 1,2

cmap = cm.get_cmap('plasma', (max_layers-min_layers+1)*(max_sublayers-min_sublayers+1)+1)

fig, ax = plt.subplots(figsize=(8,4))
# ax.set_ylim(0.1,1.65)

i = 0

for layers in range(min_layers, max_layers+1):
    for sublayers in range(min_sublayers, max_sublayers+1):

        dir_path = '..'

        data = dir_path+f'/results/linear_no_outliers/{layers}l-{sublayers}p'
        val_cost = np.load(data+'/val_cost.npy', )
        train_cost = np.load(data+'/train_cost.npy', )


        pl1, = ax.plot(train_cost,linestyle='dashed',# label=f'{layers} l, {sublayers}sl - Train', 
                       c=cmap(i),  )#alpha=0.5
        pl2, = ax.plot(val_cost, label=f'{layers} l, {sublayers}sl',
                       c=cmap(i))
        i+=1


ax.set_ylabel('MSE')
ax.set_xlabel('Iterations')
lgd = ax.legend(bbox_to_anchor=(.95, 1.3), ncol=4)#
# ax.add_artist(lgd)
# lgd1 = ax.legend([pl1,pl2],['Train','Val'], loc='lower left',bbox_to_anchor=(0.1, 0.3))#
# ax.add_artist(lgd)
#creating a folder to save the plot
dir_path = '..'
data = dir_path+f'/plots/linear'
os.makedirs(data,  0o755,  exist_ok=True)

fig.savefig(data+'/no_outliers_compare_mse.pdf',
            bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.show()
# Out:
# /var/folders/6w/dmgtk2bn4jx1mdj87jl8c6sh0000gn/T/ipykernel_18495/2063246673.py:4: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('plasma', (max_layers-min_layers+1)*(max_sublayers-min_sublayers+1)+1)

# %% [markdown]
# # Non linear encoding

# %% [markdown]
# ## Benchmark - Plot for each epoch

# %%
min_layers, max_layers = 1,4
min_sublayers, max_sublayers = 1,2

cmap = cm.get_cmap('plasma', (max_layers-min_layers+1)*(max_sublayers-min_sublayers+1)+1)

fig, ax = plt.subplots(figsize=(8,4))
# ax.set_ylim(0.05,.4)

#inset settings
axin_1 = ax.inset_axes([0.5, 0.5, 0.4, 0.45])
axin_1.set_ylim([0.035, 0.16])
axin_1.set_xlim([80, 100])
ax.indicate_inset_zoom(axin_1, edgecolor='grey',)#'black'
plt.setp(axin_1.spines.values(), color='black')

i = 0

for layers in range(min_layers, max_layers+1):
    for sublayers in range(min_sublayers, max_sublayers+1):

        dir_path = '..'

        data = dir_path+f'/results/nonlinear/{layers}l-{sublayers}p'
        val_cost = np.load(data+'/val_cost_per_epoch.npy', )
        train_cost = np.load(data+'/train_cost_per_epoch.npy', )


        pl1, = ax.plot(train_cost,linestyle='dashed',# label=f'{layers} l, {sublayers}sl - Train', 
                       c=cmap(i),  )#alpha=0.5
        axin_1.plot(train_cost,linestyle='dashed',# label=f'{layers} l, {sublayers}sl - Train', 
                    c=cmap(i),  )#alpha=0.5
        pl2, = ax.plot(val_cost, label=f'{layers} l, {sublayers}sl',
                       c=cmap(i))
        axin_1.plot(val_cost, label=f'{layers} l, {sublayers}sl',
                    c=cmap(i))
        i+=1



ax.set_ylabel('MSE')
ax.set_xlabel('Epochs')
lgd = ax.legend(bbox_to_anchor=(.0, 1.3), ncol=4, loc='upper left')#
# ax.add_artist(lgd)
# lgd1 = ax.legend([pl1,pl2],['Train','Val'], loc='lower left',bbox_to_anchor=(0.1, 0.3))#
# ax.add_artist(lgd)
#creating a folder to save the plot
dir_path = '..'
data = dir_path+f'/plots/nonlinear'
os.makedirs(data,  0o755,  exist_ok=True)

fig.savefig(data+'/benchmark_compare_mse_per_epoch.pdf',
            bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.show()
# Out:
# /var/folders/6w/dmgtk2bn4jx1mdj87jl8c6sh0000gn/T/ipykernel_18495/3282162455.py:4: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('plasma', (max_layers-min_layers+1)*(max_sublayers-min_sublayers+1)+1)

# %% [markdown]
# ## Benchmark - Plot for each iteration

# %%
min_layers, max_layers = 1,4
min_sublayers, max_sublayers = 1,2

cmap = cm.get_cmap('plasma', (max_layers-min_layers+1)*(max_sublayers-min_sublayers+1)+1)

fig, ax = plt.subplots(figsize=(8,4))
# ax.set_ylim(0.1,1.65)

i = 0

for layers in range(min_layers, max_layers+1):
    for sublayers in range(min_sublayers, max_sublayers+1):

        dir_path = '..'

        data = dir_path+f'/results/nonlinear/{layers}l-{sublayers}p'
        val_cost = np.load(data+'/val_cost.npy', )
        train_cost = np.load(data+'/train_cost.npy', )


        pl1, = ax.plot(train_cost,linestyle='dashed',# label=f'{layers} l, {sublayers}sl - Train', 
                       c=cmap(i),  )#alpha=0.5
        pl2, = ax.plot(val_cost, label=f'{layers} l, {sublayers}sl',
                       c=cmap(i))
        i+=1


ax.set_ylabel('MSE')
ax.set_xlabel('Iterations')
lgd = ax.legend(bbox_to_anchor=(.95, 1.3), ncol=4)#
# ax.add_artist(lgd)
# lgd1 = ax.legend([pl1,pl2],['Train','Val'], loc='lower left',bbox_to_anchor=(0.1, 0.3))#
# ax.add_artist(lgd)
#creating a folder to save the plot
dir_path = '..'
data = dir_path+f'/plots/nonlinear'
os.makedirs(data,  0o755,  exist_ok=True)

fig.savefig(data+'/benchmark_compare_mse.pdf',
            bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.show()
# Out:
# /var/folders/6w/dmgtk2bn4jx1mdj87jl8c6sh0000gn/T/ipykernel_18495/1616613962.py:4: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('plasma', (max_layers-min_layers+1)*(max_sublayers-min_sublayers+1)+1)

# %% [markdown]
# ## FR - No Outliers - Plot for each epoch

# %%
min_layers, max_layers = 1,4
min_sublayers, max_sublayers = 1,2

cmap = cm.get_cmap('plasma', (max_layers-min_layers+1)*(max_sublayers-min_sublayers+1)+1)

fig, ax = plt.subplots(figsize=(8,4))
# ax.set_ylim(0.05,.4)

#inset settings
axin_1 = ax.inset_axes([0.5, 0.5, 0.4, 0.45])
axin_1.set_ylim([0.035, 0.16])
axin_1.set_xlim([50, 60])
ax.indicate_inset_zoom(axin_1, edgecolor='grey',)#'black'
plt.setp(axin_1.spines.values(), color='black')

i = 0

for layers in range(min_layers, max_layers+1):
    for sublayers in range(min_sublayers, max_sublayers+1):

        dir_path = '..'

        data = dir_path+f'/results/nonlinear_no_outliers/{layers}l-{sublayers}p'
        val_cost = np.load(data+'/val_cost_per_epoch.npy', )
        train_cost = np.load(data+'/train_cost_per_epoch.npy', )


        pl1, = ax.plot(train_cost,linestyle='dashed',# label=f'{layers} l, {sublayers}sl - Train', 
                       c=cmap(i),  )#alpha=0.5
        axin_1.plot(train_cost,linestyle='dashed',# label=f'{layers} l, {sublayers}sl - Train', 
                    c=cmap(i),  )#alpha=0.5
        pl2, = ax.plot(val_cost, label=f'{layers} l, {sublayers}sl',
                       c=cmap(i))
        axin_1.plot(val_cost, label=f'{layers} l, {sublayers}sl',
                    c=cmap(i))
        i+=1



ax.set_ylabel('MSE')
ax.set_xlabel('Epochs')
lgd = ax.legend(bbox_to_anchor=(.0, 1.3), ncol=4, loc='upper left')#
# ax.add_artist(lgd)
# lgd1 = ax.legend([pl1,pl2],['Train','Val'], loc='lower left',bbox_to_anchor=(0.1, 0.3))#
# ax.add_artist(lgd)
#creating a folder to save the plot
dir_path = '..'
data = dir_path+f'/plots/nonlinear'
os.makedirs(data,  0o755,  exist_ok=True)

fig.savefig(data+'/no_outliers_compare_mse_per_epoch.pdf',
            bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.show()
# Out:
# /var/folders/6w/dmgtk2bn4jx1mdj87jl8c6sh0000gn/T/ipykernel_18495/645786749.py:4: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('plasma', (max_layers-min_layers+1)*(max_sublayers-min_sublayers+1)+1)

# %% [markdown]
# ## FR - No Outliers - Plot for each iteration

# %%
min_layers, max_layers = 1,4
min_sublayers, max_sublayers = 1,2

cmap = cm.get_cmap('plasma', (max_layers-min_layers+1)*(max_sublayers-min_sublayers+1)+1)

fig, ax = plt.subplots(figsize=(8,4))
# ax.set_ylim(0.1,1.65)

i = 0

for layers in range(min_layers, max_layers+1):
    for sublayers in range(min_sublayers, max_sublayers+1):

        dir_path = '..'

        data = dir_path+f'/results/nonlinear_no_outliers/{layers}l-{sublayers}p'
        val_cost = np.load(data+'/val_cost.npy', )
        train_cost = np.load(data+'/train_cost.npy', )


        pl1, = ax.plot(train_cost,linestyle='dashed',# label=f'{layers} l, {sublayers}sl - Train', 
                       c=cmap(i),  )#alpha=0.5
        pl2, = ax.plot(val_cost, label=f'{layers} l, {sublayers}sl',
                       c=cmap(i))
        i+=1


ax.set_ylabel('MSE')
ax.set_xlabel('Iterations')
lgd = ax.legend(bbox_to_anchor=(.95, 1.3), ncol=4)#
# ax.add_artist(lgd)
# lgd1 = ax.legend([pl1,pl2],['Train','Val'], loc='lower left',bbox_to_anchor=(0.1, 0.3))#
# ax.add_artist(lgd)
#creating a folder to save the plot
dir_path = '..'
data = dir_path+f'/plots/nonlinear'
os.makedirs(data,  0o755,  exist_ok=True)

fig.savefig(data+'/no_outliers_compare_mse.pdf',
            bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.show()
# Out:
# /var/folders/6w/dmgtk2bn4jx1mdj87jl8c6sh0000gn/T/ipykernel_18495/4024290109.py:4: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('plasma', (max_layers-min_layers+1)*(max_sublayers-min_sublayers+1)+1)

# %% [markdown]
# ## FR - With Outliers - Plot for each epochs

# %%
min_layers, max_layers = 1,4
min_sublayers, max_sublayers = 1,2

cmap = cm.get_cmap('plasma', (max_layers-min_layers+1)*(max_sublayers-min_sublayers+1)+1)

fig, ax = plt.subplots(figsize=(8,4))
# ax.set_ylim(0.05,.4)

#inset settings
axin_1 = ax.inset_axes([0.5, 0.5, 0.4, 0.45])
axin_1.set_ylim([0.035, 0.16])
axin_1.set_xlim([50, 60])
ax.indicate_inset_zoom(axin_1, edgecolor='grey',)#'black'
plt.setp(axin_1.spines.values(), color='black')

i = 0

for layers in range(min_layers, max_layers+1):
    for sublayers in range(min_sublayers, max_sublayers+1):

        dir_path = '..'

        data = dir_path+f'/results/nonlinear_with_outliers/{layers}l-{sublayers}p'
        val_cost = np.load(data+'/val_cost_per_epoch.npy', )
        train_cost = np.load(data+'/train_cost_per_epoch.npy', )


        pl1, = ax.plot(train_cost,linestyle='dashed',# label=f'{layers} l, {sublayers}sl - Train', 
                       c=cmap(i),  )#alpha=0.5
        axin_1.plot(train_cost,linestyle='dashed',# label=f'{layers} l, {sublayers}sl - Train', 
                    c=cmap(i),  )#alpha=0.5
        pl2, = ax.plot(val_cost, label=f'{layers} l, {sublayers}sl',
                       c=cmap(i))
        axin_1.plot(val_cost, label=f'{layers} l, {sublayers}sl',
                    c=cmap(i))
        i+=1



ax.set_ylabel('MSE')
ax.set_xlabel('Epochs')
lgd = ax.legend(bbox_to_anchor=(.0, 1.3), ncol=4, loc='upper left')#
# ax.add_artist(lgd)
# lgd1 = ax.legend([pl1,pl2],['Train','Val'], loc='lower left',bbox_to_anchor=(0.1, 0.3))#
# ax.add_artist(lgd)
#creating a folder to save the plot
dir_path = '..'
data = dir_path+f'/plots/nonlinear'
os.makedirs(data,  0o755,  exist_ok=True)

fig.savefig(data+'/with_outliers_compare_mse_per_epoch.pdf',
            bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.show()
# Out:
# /var/folders/6w/dmgtk2bn4jx1mdj87jl8c6sh0000gn/T/ipykernel_18495/2357004982.py:4: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('plasma', (max_layers-min_layers+1)*(max_sublayers-min_sublayers+1)+1)

# %% [markdown]
# ## FR - With Outliers - Plot for each iteration

# %%
min_layers, max_layers = 1,4
min_sublayers, max_sublayers = 1,2

cmap = cm.get_cmap('plasma', (max_layers-min_layers+1)*(max_sublayers-min_sublayers+1)+1)

fig, ax = plt.subplots(figsize=(8,4))
# ax.set_ylim(0.1,1.65)

i = 0

for layers in range(min_layers, max_layers+1):
    for sublayers in range(min_sublayers, max_sublayers+1):

        dir_path = '..'

        data = dir_path+f'/results/nonlinear_with_outliers/{layers}l-{sublayers}p'
        val_cost = np.load(data+'/val_cost.npy', )
        train_cost = np.load(data+'/train_cost.npy', )


        pl1, = ax.plot(train_cost,linestyle='dashed',# label=f'{layers} l, {sublayers}sl - Train', 
                       c=cmap(i),  )#alpha=0.5
        pl2, = ax.plot(val_cost, label=f'{layers} l, {sublayers}sl',
                       c=cmap(i))
        i+=1


ax.set_ylabel('MSE')
ax.set_xlabel('Iterations')
lgd = ax.legend(bbox_to_anchor=(.95, 1.3), ncol=4)#
# ax.add_artist(lgd)
# lgd1 = ax.legend([pl1,pl2],['Train','Val'], loc='lower left',bbox_to_anchor=(0.1, 0.3))#
# ax.add_artist(lgd)
#creating a folder to save the plot
dir_path = '..'
data = dir_path+f'/plots/nonlinear'
os.makedirs(data,  0o755,  exist_ok=True)

fig.savefig(data+'/with_outliers_compare_mse.pdf',
            bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.show()
# Out:
# /var/folders/6w/dmgtk2bn4jx1mdj87jl8c6sh0000gn/T/ipykernel_18495/3879938150.py:4: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('plasma', (max_layers-min_layers+1)*(max_sublayers-min_sublayers+1)+1)

# %% [markdown]
# # Advanced tasks

# %% [markdown]
# ## Non linear - Basic ansatz - With outliers

# %%
min_layers, max_layers = 1,4
min_sublayers, max_sublayers = 1,2

cmap = cm.get_cmap('plasma', (max_layers-min_layers+1)*(max_sublayers-min_sublayers+1)+1)

fig, ax = plt.subplots(figsize=(8,4))
# ax.set_ylim(0.05,.4)

#inset settings
axin_1 = ax.inset_axes([0.5, 0.5, 0.4, 0.45])
axin_1.set_ylim([0.1, 0.2])
axin_1.set_xlim([50, 60])
ax.indicate_inset_zoom(axin_1, edgecolor='grey',)#'black'
plt.setp(axin_1.spines.values(), color='black')

i = 0

for layers in range(min_layers, max_layers+1):
    for sublayers in range(min_sublayers, max_sublayers+1):

        dir_path = '..'

        data = dir_path+f'/results/nonlinear_basic_ans_with_outliers/{layers}l-{sublayers}p'
        val_cost = np.load(data+'/val_cost_per_epoch.npy', )
        train_cost = np.load(data+'/train_cost_per_epoch.npy', )


        pl1, = ax.plot(train_cost,linestyle='dashed',# label=f'{layers} l, {sublayers}sl - Train', 
                       c=cmap(i),  )#alpha=0.5
        axin_1.plot(train_cost,linestyle='dashed',# label=f'{layers} l, {sublayers}sl - Train', 
                    c=cmap(i),  )#alpha=0.5
        pl2, = ax.plot(val_cost, label=f'{layers} l, {sublayers}sl',
                       c=cmap(i))
        axin_1.plot(val_cost, label=f'{layers} l, {sublayers}sl',
                    c=cmap(i))
        i+=1



ax.set_ylabel('MSE')
ax.set_xlabel('Epochs')
lgd = ax.legend(bbox_to_anchor=(.0, 1.3), ncol=4, loc='upper left')#
# ax.add_artist(lgd)
# lgd1 = ax.legend([pl1,pl2],['Train','Val'], loc='lower left',bbox_to_anchor=(0.1, 0.3))#
# ax.add_artist(lgd)
#creating a folder to save the plot
dir_path = '..'
data = dir_path+f'/plots/advanced'
os.makedirs(data,  0o755,  exist_ok=True)

fig.savefig(data+'/basic_ans_with_outliers_compare_mse_per_epoch.pdf',
            bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.show()
# Out:
# /var/folders/6w/dmgtk2bn4jx1mdj87jl8c6sh0000gn/T/ipykernel_18495/1320409043.py:4: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('plasma', (max_layers-min_layers+1)*(max_sublayers-min_sublayers+1)+1)

# %% [markdown]
# ## Non linear - Basic ansatz - Without outliers

# %%
min_layers, max_layers = 1,4
min_sublayers, max_sublayers = 1,2

cmap = cm.get_cmap('plasma', (max_layers-min_layers+1)*(max_sublayers-min_sublayers+1)+1)

fig, ax = plt.subplots(figsize=(8,4))
# ax.set_ylim(0.05,.4)

#inset settings
axin_1 = ax.inset_axes([0.5, 0.5, 0.4, 0.45])
axin_1.set_ylim([0.1, 0.2])
axin_1.set_xlim([50, 60])
ax.indicate_inset_zoom(axin_1, edgecolor='grey',)#'black'
plt.setp(axin_1.spines.values(), color='black')

i = 0

for layers in range(min_layers, max_layers+1):
    for sublayers in range(min_sublayers, max_sublayers+1):

        dir_path = '..'

        data = dir_path+f'/results/nonlinear_basic_ans_without_outliers/{layers}l-{sublayers}p'
        val_cost = np.load(data+'/val_cost_per_epoch.npy', )
        train_cost = np.load(data+'/train_cost_per_epoch.npy', )


        pl1, = ax.plot(train_cost,linestyle='dashed',# label=f'{layers} l, {sublayers}sl - Train', 
                       c=cmap(i),  )#alpha=0.5
        axin_1.plot(train_cost,linestyle='dashed',# label=f'{layers} l, {sublayers}sl - Train', 
                    c=cmap(i),  )#alpha=0.5
        pl2, = ax.plot(val_cost, label=f'{layers} l, {sublayers}sl',
                       c=cmap(i))
        axin_1.plot(val_cost, label=f'{layers} l, {sublayers}sl',
                    c=cmap(i))
        i+=1



ax.set_ylabel('MSE')
ax.set_xlabel('Epochs')
lgd = ax.legend(bbox_to_anchor=(.0, 1.3), ncol=4, loc='upper left')#
# ax.add_artist(lgd)
# lgd1 = ax.legend([pl1,pl2],['Train','Val'], loc='lower left',bbox_to_anchor=(0.1, 0.3))#
# ax.add_artist(lgd)
#creating a folder to save the plot
dir_path = '..'
data = dir_path+f'/plots/advanced'
os.makedirs(data,  0o755,  exist_ok=True)

fig.savefig(data+'/basic_ans_without_outliers_compare_mse_per_epoch.pdf',
            bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.show()
# Out:
# /var/folders/6w/dmgtk2bn4jx1mdj87jl8c6sh0000gn/T/ipykernel_18495/3323361130.py:4: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('plasma', (max_layers-min_layers+1)*(max_sublayers-min_sublayers+1)+1)

# %% [markdown]
# ## Non linear - Random ans - Without outliers

# %%
min_layers, max_layers = 1,4
min_sublayers, max_sublayers = 1,2

cmap = cm.get_cmap('plasma', (max_layers-min_layers+1)*(max_sublayers-min_sublayers+1)+1)

fig, ax = plt.subplots(figsize=(8,4))
# ax.set_ylim(0.05,.4)

#inset settings
axin_1 = ax.inset_axes([0.5, 0.5, 0.4, 0.45])
axin_1.set_ylim([0.15, 0.285])
axin_1.set_xlim([50, 60])
ax.indicate_inset_zoom(axin_1, edgecolor='grey',)#'black'
plt.setp(axin_1.spines.values(), color='black')

i = 0

for layers in range(min_layers, max_layers+1):
    for sublayers in range(min_sublayers, max_sublayers+1):

        dir_path = '..'

        data = dir_path+f'/results/nonlinear_random_ans_without_outliers/{layers}l-{sublayers}p'
        val_cost = np.load(data+'/val_cost_per_epoch.npy', )
        train_cost = np.load(data+'/train_cost_per_epoch.npy', )


        pl1, = ax.plot(train_cost,linestyle='dashed',# label=f'{layers} l, {sublayers}sl - Train', 
                       c=cmap(i),  )#alpha=0.5
        axin_1.plot(train_cost,linestyle='dashed',# label=f'{layers} l, {sublayers}sl - Train', 
                    c=cmap(i),  )#alpha=0.5
        pl2, = ax.plot(val_cost, label=f'{layers} l, {sublayers}sl',
                       c=cmap(i))
        axin_1.plot(val_cost, label=f'{layers} l, {sublayers}sl',
                    c=cmap(i))
        i+=1



ax.set_ylabel('MSE')
ax.set_xlabel('Epochs')
lgd = ax.legend(bbox_to_anchor=(.0, 1.3), ncol=4, loc='upper left')#
# ax.add_artist(lgd)
# lgd1 = ax.legend([pl1,pl2],['Train','Val'], loc='lower left',bbox_to_anchor=(0.1, 0.3))#
# ax.add_artist(lgd)
#creating a folder to save the plot
dir_path = '..'
data = dir_path+f'/plots/advanced'
os.makedirs(data,  0o755,  exist_ok=True)

fig.savefig(data+'/random_ans_without_outliers_compare_mse_per_epoch.pdf',
            bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.show()
# Out:
# /var/folders/6w/dmgtk2bn4jx1mdj87jl8c6sh0000gn/T/ipykernel_18495/3813477387.py:4: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('plasma', (max_layers-min_layers+1)*(max_sublayers-min_sublayers+1)+1)
