# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_theme()

# %% [markdown]
# ## Benchmark

# %%
df = pd.read_csv('./benchmark.csv', sep=';', index_col=0)
df.head()
# Out:
#                 1-1       1-2       2-1       2-2       3-1       3-2  \
# Linear     0.348689  0.130796  0.559614  0.112245  0.124465  0.071926
# Nonlinear  0.231683  0.148893  0.148041  0.083638  0.092909  0.085767
#
#                 4-1       4-2
# Linear     0.561026  0.088074
# Nonlinear  0.264359  0.072306

# %% [markdown]
# Best MSE value: linear L3 S2

# %%
_, ax = plt.subplots(1, 1)

X = ['L'+x.split('-')[0] + 'S'+x.split('-')[1] for x in df.columns.values]
X_axis = np.arange(len(X))

y_linear = df.loc['Linear'].values
y_nonlinear = df.loc['Nonlinear'].values

ax.bar(X_axis - 0.2, y_linear, 0.4, label = 'Linear')
ax.bar(X_axis + 0.2, y_nonlinear, 0.4, label = 'Non Linear')

plt.xticks(X_axis, X)
ax.set_xlabel("Composition of Layers and Sublayers")
ax.set_ylabel("MSE")
ax.set_title("Hyperparameter tuning")
ax.legend()
plt.show()

# %% [markdown]
# ## Features reduction with outliers

# %% [markdown]
# Best value: non linear L2 S4

# %%
df = pd.read_csv('./mse_with_outliers.csv', sep=';', index_col=0)
df.head()
# Out:
#                 1-1       1-2       1-3       1-4       2-1       2-2  \
# Linear     0.352963  0.145880  0.119492  0.124232  0.574800  0.356469
# Nonlinear  0.227557  0.145739  0.106351  0.095862  0.190378  0.169233
#
#                 2-3       2-4       3-1       3-2       3-3       3-4  \
# Linear     0.088066  0.076107  0.295111  0.303078  0.102736  0.090179
# Nonlinear  0.070899  0.042347  0.536350  0.314043  0.066882  0.068315
#
#                 4-1       4-2       4-3       4-4
# Linear     0.374941  0.228603  0.244148  0.122307
# Nonlinear  0.301668  0.186685  0.205060  0.086126

# %%
_, ax = plt.subplots(1, 1, figsize=(15, 8))

X = ['L'+x.split('-')[0] + 'S'+x.split('-')[1] for x in df.columns.values]
X_axis = np.arange(len(X))

y_linear = df.loc['Linear'].values
y_nonlinear = df.loc['Nonlinear'].values

ax.bar(X_axis - 0.2, y_linear, 0.4, label = 'Linear')
ax.bar(X_axis + 0.2, y_nonlinear, 0.4, label = 'Non Linear')

plt.xticks(X_axis, X)
ax.set_xlabel("Composition of Layers and Sublayers")
ax.set_ylabel("MSE")
ax.set_title("Hyperparameter tuning")
ax.legend()
plt.show()

# %% [markdown]
# ## Features reduction without outliers

# %% [markdown]
# Best value: non linear L2 S4

# %%
df = pd.read_csv('./mse_no_outliers.csv', sep=';', index_col=0)
df.head()
# Out:
#                 1-1       1-2       1-3       1-4       2-1       2-2  \
# Linear     0.359998  0.169735  0.153759  0.107024  0.610651  0.245531
# Nonlinear  0.253408  0.149050  0.104842  0.092726  0.177027  0.254393
#
#                 2-3       2-4       3-1       3-2       3-3       3-4  \
# Linear     0.092684  0.066548  0.269315  0.281562  0.101436  0.093561
# Nonlinear  0.079816  0.042104  0.341288  0.250393  0.050770  0.075330
#
#                 4-1       4-2       4-3       4-4
# Linear     0.436983  0.201098  0.229084  0.111301
# Nonlinear  0.343796  0.247224  0.222689  0.094615

# %%
_, ax = plt.subplots(1, 1, figsize=(15, 8))

X = ['L'+x.split('-')[0] + 'S'+x.split('-')[1] for x in df.columns.values]
X_axis = np.arange(len(X))

y_linear = df.loc['Linear'].values
y_nonlinear = df.loc['Nonlinear'].values

ax.bar(X_axis - 0.2, y_linear, 0.4, label = 'Linear')
ax.bar(X_axis + 0.2, y_nonlinear, 0.4, label = 'Non Linear')

plt.xticks(X_axis, X)
ax.set_xlabel("Composition of Layers and Sublayers")
ax.set_ylabel("MSE")
ax.set_title("Hyperparameter tuning")
ax.legend()
plt.show()
